# %%
import geopandas as gpd
from shapely.ops import unary_union
from dataset_functions import *
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df_location = pd.read_stata('./classifications_data/location.dta')
df_location.head()
# Out:
#   location_id location_code location_name_short_en    level  parent_id
# 0           0           ABW                  Aruba  country      356.0
# 1           1           AFG            Afghanistan  country      353.0
# 2           2           AGO                 Angola  country      352.0
# 3           3           AIA               Anguilla  country      356.0
# 4           4           ALB                Albania  country      355.0

# %%
countries_path = './classifications_data/ne_110m_admin_0_countries.geojson'
gdf = gpd.read_file(countries_path)
print(gdf.head())
print(gdf.columns)
# Out:
#         featurecla  scalerank  LABELRANK                   SOVEREIGNT SOV_A3  \
# 0  Admin-0 country          1          6                         Fiji    FJI
# 1  Admin-0 country          1          3  United Republic of Tanzania    TZA
# 2  Admin-0 country          1          7               Western Sahara    SAH
# 3  Admin-0 country          1          2                       Canada    CAN
# 4  Admin-0 country          1          2     United States of America    US1
#
#    ADM0_DIF  LEVEL               TYPE                        ADMIN ADM0_A3  \
# 0         0      2  Sovereign country                         Fiji     FJI
# 1         0      2  Sovereign country  United Republic of Tanzania     TZA
# 2         0      2      Indeterminate               Western Sahara     SAH
# 3         0      2  Sovereign country                       Canada     CAN
# 4         1      2            Country     United States of America     USA
#
#    ...     FCLASS_TR     FCLASS_ID     FCLASS_PL  FCLASS_GR FCLASS_IT  \
# 0  ...          None          None          None       None      None
# 1  ...          None          None          None       None      None
# 2  ...  Unrecognized  Unrecognized  Unrecognized       None      None
# 3  ...          None          None          None       None      None
# 4  ...          None          None          None       None      None
#
#       FCLASS_NL  FCLASS_SE FCLASS_BD FCLASS_UA  \
# 0          None       None      None      None
# 1          None       None      None      None
# 2  Unrecognized       None      None      None
# 3          None       None      None      None
# 4          None       None      None      None
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#
# [5 rows x 162 columns]
# Index(['featurecla', 'scalerank', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'ADMIN', 'ADM0_A3',
#        ...
#        'FCLASS_TR', 'FCLASS_ID', 'FCLASS_PL', 'FCLASS_GR', 'FCLASS_IT',
#        'FCLASS_NL', 'FCLASS_SE', 'FCLASS_BD', 'FCLASS_UA', 'geometry'],
#       dtype='object', length=162)
# C:\Users\MaximilianGangloff\anaconda3\lib\site-packages\geopandas\array.py:85: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out

# %% [markdown]
# Only take the colomns that are needed:
# - ISO_A2
# - ISO_A3
# - ADMIN
# - POP_EST
# - GDP_MD

# %%
gdf_resized = gdf[['ISO_A2', 'ISO_A3', 'ADMIN', 'POP_EST', 'GDP_MD', 'geometry']]
print(gdf_resized.shape)
gdf_resized.head()
# Out:
# (177, 6)
#   ISO_A2 ISO_A3                        ADMIN      POP_EST    GDP_MD  \
# 0     FJ    FJI                         Fiji     889953.0      5496
# 1     TZ    TZA  United Republic of Tanzania   58005463.0     63177
# 2     EH    ESH               Western Sahara     603253.0       907
# 3     CA    CAN                       Canada   37589262.0   1736425
# 4     US    USA     United States of America  328239523.0  21433226
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
gdf_resized.loc[gdf_resized['ISO_A3'] == '-99']
# Out:
#     ISO_A2 ISO_A3            ADMIN    POP_EST  GDP_MD  \
# 160    -99    -99  Northern Cyprus   326000.0    3600
# 167    -99    -99       Somaliland  5096159.0   17836
# 174     XK    -99           Kosovo  1794248.0    7926
#
#                                               geometry
# 160  POLYGON ((32.73178 35.14003, 32.80247 35.14550...
# 167  POLYGON ((48.94821 11.41062, 48.94821 11.41062...
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...

# %%
gdf_resized.loc[gdf_resized['ADMIN'].str.contains('Kosovo'), 'ISO_A3'] = 'XKK'

# %%
def merge_rows_geojson(gdf, countries_to_merge):
    """
    Merge rows of geojson combining their geometry and adding their population and GDP. 
    Merges the countries into the entry that has a valid ```ISO_A2``` and valid ```ISO_A3```.
    If there are multiple entries, then the countries are merged into ```countries_to_merge[0]```.

    Args:
        gdf: geopandas DataFrame
        countries_to_merge: List containing the countries to merge.
    """
    df_countries = gdf.loc[gdf['ADMIN'].isin(countries_to_merge)]
    df_valid_countries = df_countries[(df_countries['ISO_A2'] != '-99') & (df_countries['ISO_A3'] != '-99')]
    valid_country = df_valid_countries.iloc[0]['ADMIN'] if len(df_valid_countries.index) == 1 else countries_to_merge[0]

    polygons = [polygon for polygon in gdf_resized.loc[gdf_resized['ADMIN'].isin(countries_to_merge), 'geometry']]
    merged_polygon = gpd.GeoSeries(unary_union(polygons))
    gdf.loc[gdf_resized['ADMIN'] == valid_country, 'geometry'] = merged_polygon[0]

    for idx, country in enumerate(countries_to_merge):
        if country != valid_country:
            gdf.loc[gdf['ADMIN'] == valid_country, 'POP_EST'] += df_countries.iloc[idx]['POP_EST']
            gdf.loc[gdf['ADMIN'] == valid_country, 'GDP_MD'] += df_countries.iloc[idx]['GDP_MD']
           
    df_invalid = df_countries[(df_countries['ISO_A2'] == '-99') | (df_countries['ISO_A3'] == '-99')]

    gdf.drop(df_invalid.index, inplace=True)

# %%
gdf_resized.loc[gdf_resized['ADMIN'].str.contains('Somal')]
# Out:
#     ISO_A2 ISO_A3       ADMIN     POP_EST  GDP_MD  \
# 12      SO    SOM     Somalia  10192317.3    4719
# 167    -99    -99  Somaliland   5096159.0   17836
#
#                                               geometry
# 12   POLYGON ((41.58513 -1.68325, 40.99300 -0.85829...
# 167  POLYGON ((48.94821 11.41062, 48.94821 11.41062...

# %%
merge_rows_geojson(gdf_resized, ['Somalia', 'Somaliland'])

# %%
gdf_resized.loc[gdf_resized['ADMIN'].str.contains('Somal')]
# Out:
#    ISO_A2 ISO_A3    ADMIN     POP_EST  GDP_MD  \
# 12     SO    SOM  Somalia  15288476.3   22555
#
#                                              geometry
# 12  POLYGON ((40.99300 -0.85829, 40.98105 2.78452,...

# %%
gdf_resized.loc[gdf_resized['ADMIN'].str.contains('Cyprus')]
# Out:
#     ISO_A2 ISO_A3            ADMIN    POP_EST  GDP_MD  \
# 160    -99    -99  Northern Cyprus   326000.0    3600
# 161     CY    CYP           Cyprus  1198575.0   24948
#
#                                               geometry
# 160  POLYGON ((32.73178 35.14003, 32.80247 35.14550...
# 161  POLYGON ((32.73178 35.14003, 32.91957 35.08783...

# %%
merge_rows_geojson(gdf_resized, ['Northern Cyprus', 'Cyprus'])

# %%
gdf_resized.loc[gdf_resized['ADMIN'].str.contains('Cyprus')]
# Out:
#     ISO_A2 ISO_A3   ADMIN    POP_EST  GDP_MD  \
# 161     CY    CYP  Cyprus  1524575.0   28548
#
#                                               geometry
# 161  POLYGON ((34.00488 34.97810, 32.97983 34.57187...

# %% [markdown]
# ### Join trade data with geojson

# %%
df_years = contries_table_1969_2019()
# Out:
# C:\Users\MaximilianGangloff\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3437: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(df_years.shape)
df_years.head()
# Out:
# (258, 813)
#   location_code  total_trades_1962  export_value_1962  import_value_1962  \
# 0           ABW               -1.0               -1.0               -1.0
# 1           AFG        200965233.0         81991329.0        118973904.0
# 2           AGO        249036901.0        131266146.0        117770755.0
# 3           AIA               -1.0               -1.0               -1.0
# 4           ALB         11221374.0          2301674.0          8919700.0
#
#    percentage_exports_1962 highest_export_to_1962  percentage_imports_1962  \
# 0                -1.000000                     -1                -1.000000
# 1                 0.064978                    RUS                 0.094286
# 2                 0.104028                    USA                 0.093333
# 3                -1.000000                     -1                -1.000000
# 4                 0.001824                    ITA                 0.007069
#
#    percentage_total_1962  percentage_trade_to_exp_1962  \
# 0              -1.000000                     -1.000000
# 1               0.047143                     31.443399
# 2               0.046666                     29.491607
# 3              -1.000000                     -1.000000
# 4               0.003534                     54.749978
#
#   highest_import_from_1962  ...  highest_export_to_2019  \
# 0                       -1  ...                     ANS
# 1                      RUS  ...                     PAK
# 2                      PRT  ...                     CHN
# 3                       -1  ...                     CHL
# 4                      FRA  ...                     ITA
#
#    percentage_imports_2019  percentage_total_2019  \
# 0                 0.008876               0.004438
# 1                 0.049454               0.024727
# 2                 0.051003               0.025502
# 3                 0.000971               0.000485
# 4                 0.031245               0.015623
#
#    percentage_trade_to_exp_2019  highest_import_from_2019  \
# 0                     46.897879                       ANS
# 1                     40.377646                       ARE
# 2                     62.742091                       CHN
# 3                     54.942945                       USA
# 4                     43.613567                       ITA
#
#    trade_value_exported_2019  percentage_exp_all_trades_2019  \
# 0               7.104166e+07                        0.000390
# 1               5.606157e+08                        0.003074
# 2               1.864664e+10                        0.102259
# 3               2.058563e+07                        0.000113
# 4               1.242825e+09                        0.006816
#
#    trade_value_imported_2019  percentage_imp_all_trades_2019  \
# 0               5.281396e+08                        0.002896
# 1               1.274326e+09                        0.006988
# 2               2.057495e+09                        0.011283
# 3               8.857281e+07                        0.000486
# 4               1.517889e+09                        0.008324
#
#   percentage_trade_to_imp_2019
# 0                    32.630982
# 1                    14.131309
# 2                    22.122846
# 3                    50.047787
# 4                    26.641139
#
# [5 rows x 813 columns]

# %%
gdf_countries = pd.concat([gdf_resized.set_index('ISO_A3'), df_years.set_index('location_code')], axis=1).reindex(gdf_resized.set_index('ISO_A3').index).reset_index()
gdf_countries.insert(len(gdf_countries.columns)-1, 'geometry', gdf_countries.pop('geometry'))
gdf_countries.head()
# Out:
#   ISO_A3 ISO_A2                        ADMIN      POP_EST      GDP_MD  \
# 0    FJI     FJ                         Fiji     889953.0      5496.0
# 1    TZA     TZ  United Republic of Tanzania   58005463.0     63177.0
# 2    ESH     EH               Western Sahara     603253.0       907.0
# 3    CAN     CA                       Canada   37589262.0   1736425.0
# 4    USA     US     United States of America  328239523.0  21433226.0
#
#    total_trades_1962  export_value_1962  import_value_1962  \
# 0       3.216818e+07       1.316930e+07       1.899888e+07
# 1      -1.000000e+00      -1.000000e+00      -1.000000e+00
# 2      -1.000000e+00      -1.000000e+00      -1.000000e+00
# 3       1.171900e+10       6.126400e+09       5.592603e+09
# 4       3.760836e+10       2.183618e+10       1.577218e+10
#
#    percentage_exports_1962 highest_export_to_1962  ...  \
# 0                 0.010437                    GBR  ...
# 1                -1.000000                     -1  ...
# 2                -1.000000                     -1  ...
# 3                 4.855140                    USA  ...
# 4                17.305058                    CAN  ...
#
#    percentage_imports_2019  percentage_total_2019  \
# 0                 0.013959               0.006980
# 1                 0.072466               0.036233
# 2                 0.000116               0.000058
# 3                 2.526711               1.263356
# 4                12.794311               6.397155
#
#    percentage_trade_to_exp_2019 highest_import_from_2019  \
# 0                     24.750338                      SGP
# 1                     18.437558                      CHN
# 2                     71.323643                      USA
# 3                     75.160112                      USA
# 4                     17.684965                      CHN
#
#    trade_value_exported_2019  percentage_exp_all_trades_2019  \
# 0               2.386527e+08                        0.001309
# 1               7.006220e+08                        0.003842
# 2               1.690018e+06                        0.000009
# 3               3.308538e+11                        1.814409
# 4               2.886552e+11                        1.582991
#
#    trade_value_imported_2019  percentage_imp_all_trades_2019  \
# 0               3.971354e+08                        0.002178
# 1               3.814731e+09                        0.020920
# 2               2.119777e+07                        0.000116
# 3               2.886552e+11                        1.582991
# 4               3.873485e+11                        2.124227
#
#    percentage_trade_to_imp_2019  \
# 0                     15.602060
# 1                     28.868805
# 2                    100.000000
# 3                     62.650255
# 4                     16.602903
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#
# [5 rows x 818 columns]

# %%
gdf_countries.to_file('countries.geojson', driver="GeoJSON")
